# %%
import pandas as pd 
import numpy as np

# %%
#periods number of dates to generate 
dates =pd.date_range('1/1/2024',periods= 500)
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10',
#                ...
#                '2025-05-05', '2025-05-06', '2025-05-07', '2025-05-08',
#                '2025-05-09', '2025-05-10', '2025-05-11', '2025-05-12',
#                '2025-05-13', '2025-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
#randn range (+3 to -3)
data1=np.random.randn(500,3) #shape(row,column) 
data1
# Out:
# array([[ 5.66460534e-01,  4.36804929e-01,  2.32069310e-01],
#        [-3.80672509e-04, -5.38540787e-01,  6.72169743e-02],
#        [ 5.55884297e-01,  1.88585422e-01, -2.45992187e+00],
#        ...,
#        [-7.86952884e-02, -7.62182779e-01,  2.11835708e-01],
#        [-5.96974000e-01, -1.21353224e+00, -9.35102862e-01],
#        [-1.91694157e+00,  7.30466391e-01, -4.66202565e-01]])

# %%
df1= pd.DataFrame(data= data1,index=dates,columns=['A','B','C'])

# %%
df1
# Out:
#                    A         B         C
# 2024-01-01  0.566461  0.436805  0.232069
# 2024-01-02 -0.000381 -0.538541  0.067217
# 2024-01-03  0.555884  0.188585 -2.459922
# 2024-01-04  0.632684  0.075460  0.190421
# 2024-01-05 -2.664097  0.829365 -1.261037
# ...              ...       ...       ...
# 2025-05-10  0.944398 -0.298131 -0.054149
# 2025-05-11 -0.309692 -1.369468  1.375949
# 2025-05-12 -0.078695 -0.762183  0.211836
# 2025-05-13 -0.596974 -1.213532 -0.935103
# 2025-05-14 -1.916942  0.730466 -0.466203
#
# [500 rows x 3 columns]

# %%
df1['D']=np.random.rand(500) #rand range(0 to 1)

# %%
df1
# Out:
#                    A         B         C         D
# 2024-01-01  0.566461  0.436805  0.232069  0.790962
# 2024-01-02 -0.000381 -0.538541  0.067217  0.765830
# 2024-01-03  0.555884  0.188585 -2.459922  0.149640
# 2024-01-04  0.632684  0.075460  0.190421  0.799571
# 2024-01-05 -2.664097  0.829365 -1.261037  0.669304
# ...              ...       ...       ...       ...
# 2025-05-10  0.944398 -0.298131 -0.054149  0.269649
# 2025-05-11 -0.309692 -1.369468  1.375949  0.972184
# 2025-05-12 -0.078695 -0.762183  0.211836  0.064464
# 2025-05-13 -0.596974 -1.213532 -0.935103  0.819963
# 2025-05-14 -1.916942  0.730466 -0.466203  0.385043
#
# [500 rows x 4 columns]

# %%
data2=np.random.rand(20,3)
df2=pd.DataFrame(data=data2,columns=['X','Y','Z'])

# %%
df2
# Out:
#            X         Y         Z
# 0   0.207764  0.732979  0.084380
# 1   0.419950  0.601182  0.635069
# 2   0.577999  0.436597  0.511807
# 3   0.933263  0.304664  0.659527
# 4   0.100627  0.847553  0.819881
# 5   0.069325  0.237084  0.467206
# 6   0.026340  0.038924  0.279271
# 7   0.766859  0.139797  0.774763
# 8   0.147401  0.852648  0.971793
# 9   0.812877  0.384446  0.648852
# 10  0.774125  0.890381  0.765024
# 11  0.699383  0.623911  0.355518
# 12  0.256167  0.137591  0.650233
# 13  0.575893  0.926162  0.797792
# 14  0.548247  0.206874  0.743506
# 15  0.799359  0.767487  0.240016
# 16  0.903926  0.393186  0.879235
# 17  0.763606  0.920162  0.563018
# 18  0.395959  0.599735  0.327466
# 19  0.283122  0.900585  0.709529

# %%
#Histogram 
df1['A'].hist(edgecolor='black',bins=30,figsize=(10,5));

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot') #bmh, dark_background, five38

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
df2['X'].hist(bins=50)
# Out:
# <Axes: >

# %%
df2['X'].plot() #gives line chart by default

# %%
df2['X'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
#stacked data
df2.plot(kind='area') #line chart and area chart same
# Out:
# <Axes: >

# %%
#bar plot
df2['X'].plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: >

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
#stacked bar
df2.plot(kind='bar',stacked=True,figsize=(10,5))
# Out:
# <Axes: >

# %%
#horizontal  
df2.plot(kind='barh',stacked=True,figsize=(10,5))
# Out:
# <Axes: >

# %%
#scatter plot
df1.plot.scatter(x='A',y='B',c='.8',cmap='coolwarm',figsize=(10,5)); #cmap-->color tone,c is opacity
# Out:
# C:\Users\nafiu\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
df1.plot.line(x='A',y='B',figsize=(10,5),lw=.3) #same as scatter
# Out:
# <Axes: xlabel='A'>

# %%
#bubble chart---> 3 variable chart 
df1.plot.scatter(x='A',y='B',c='D',cmap='coolwarm',figsize=(10,5)) #this color is dependent on the value of D column 
#s=value---> size of bubbles...can place Other Column here as well
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
#size according to the value of D column 
df1.plot.scatter(x='A',y='B',s=df1['D']*20,c='D',cmap='coolwarm',figsize=(10,5))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
#hexbin--->shows the density of the data 
df1.plot.hexbin(x='A',y='B',gridsize=50,cmap='Oranges',figsize=(10,5))
# Out:
# <Axes: xlabel='A', ylabel='B'>
